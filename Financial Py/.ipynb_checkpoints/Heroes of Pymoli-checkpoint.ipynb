# %%
import numpy as np
import pandas as pd

# %%
heroesP=pd.read_csv("purchase_data.csv")
heroesP.head(5)
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
N_Players=len(heroesP["SN"].unique().tolist())            #N_Players2=heroesP["SN"].value_counts().count()
N_UniqueI=len(heroesP["Item ID"].unique().tolist())       #N_UniqueI2=heroesP["Item ID"].value_counts().count()
N_Purchases=heroesP["Purchase ID"].count()
T_Rev=heroesP["Price"].sum()
Aver_P=T_Rev/N_Purchases

print("Total Number of Players Method1",N_Players)
print("Number of Unique Items Method1",N_UniqueI)
print("Average PurchasePrice",Aver_P)
print("Number of Purchases",N_Purchases)
print("Total Revenue",T_Rev)
# Out:
# Total Number of Players Method1 576
# Number of Unique Items Method1 183
# Average PurchasePrice 3.0509871794871795
# Number of Purchases 780
# Total Revenue 2379.77

# %%
GenderCl=heroesP.groupby("Gender")["SN"].nunique(dropna=True)

# %%
GenderCl=GenderCl.reset_index()

# %%
GenderCl["% PLayers"]=GenderCl["SN"]*100/N_Players

# %%
GenderCl=GenderCl.rename(columns={"SN":"# of Players"})
CC=GenderCl.set_index("Gender")

# %%
GenderP=(heroesP.groupby("Gender")["Purchase ID"].nunique(dropna=True)).reset_index()
GenderP=GenderP.set_index("Gender")
GenderP=GenderP.rename(columns={"Purchase ID":"Amount of Purchases"})

# %%
GenderT=(heroesP.groupby("Gender")["Price"].sum()).reset_index()
GenderT=(GenderT.rename(columns={"Price":"Total Purchase Value"})).set_index("Gender")
GenderT["Average Purchase Value"]=GenderT["Total Purchase Value"]/GenderP["Amount of Purchases"]

# %%
mergT=pd.merge(GenderP,GenderT,on="Gender")
mergTT=pd.merge(CC,mergT,on="Gender")
mergTT["% Purchases"]=GenderP["Amount of Purchases"]*100/N_Purchases
FinalG=mergTT[["# of Players","% PLayers","Amount of Purchases","% Purchases","Total Purchase Value",
              "Average Purchase Value"]]
FinalG
# Out:
#                        # of Players  % PLayers  Amount of Purchases  \
# Gender
# Female                           81  14.062500                  113
# Male                            484  84.027778                  652
# Other / Non-Disclosed            11   1.909722                   15
#
#                        % Purchases  Total Purchase Value  \
# Gender
# Female                   14.487179                361.94
# Male                     83.589744               1967.64
# Other / Non-Disclosed     1.923077                 50.19
#
#                        Average Purchase Value
# Gender
# Female                               3.203009
# Male                                 3.017853
# Other / Non-Disclosed                3.346000

# %%
AvPP=(heroesP.groupby(["Gender","SN"])["Price"].mean()).reset_index()
AvPP.head()
# Out:
#    Gender             SN  Price
# 0  Female    Adastirin33   4.48
# 1  Female  Aerithllora36   4.32
# 2  Female     Aethedru70   3.54
# 3  Female       Aidain51   3.45
# 4  Female      Aiduesu86   4.48

# %%
bins=[5,9,13,17,21,25,29,33,37,41,45]
group_labels=["05 to 09","10 to 13","14 to 17","18 to 21","22 to 25","26 to 29",
              "30 to 33","34 to 37","38 to 41","42 to 45"]

heroesP["Age Groups"]=pd.cut(heroesP["Age"],bins=bins,labels=group_labels)
#dfAge["Age Group"]=pd.cut(heroesP["Age"],bins=bins,labels=group_labels)
heroesP.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Groups
# 0  Extraction, Quickblade Of Trembling Hands   3.53   18 to 21
# 1                          Frenzied Scimitar   1.56   38 to 41
# 2                               Final Critic   4.88   22 to 25
# 3                                Blindscythe   3.27   22 to 25
# 4                                       Fury   1.44   22 to 25

# %%
heroesG=heroesP.groupby("Age Groups")
nP=(heroesG["Purchase ID"].count()).reset_index().set_index("Age Groups")
nT=(heroesG["Price"].sum()).reset_index().set_index("Age Groups")
nPT=pd.merge(nP,nT,on="Age Groups")
nPT["Average Price"]=nPT["Price"]/nPT["Purchase ID"]
nPT
# Out:
#             Purchase ID   Price  Average Price
# Age Groups
# 05 to 09             23   77.13       3.353478
# 10 to 13             26   75.87       2.918077
# 14 to 17             89  267.60       3.006742
# 18 to 21            210  647.26       3.082190
# 22 to 25            263  800.90       3.045247
# 26 to 29             42  111.10       2.645238
# 30 to 33             64  191.87       2.997969
# 34 to 37             35  112.33       3.209429
# 38 to 41             23   80.72       3.509565
# 42 to 45              5   14.99       2.998000

# %%
AvP=heroesP.groupby(["Age Groups","SN"])["Price"].mean()
AvP.reset_index().head()
# Out:
#   Age Groups            SN  Price
# 0   05 to 09  Anallorgue57  2.850
# 1   05 to 09    Chadjask77  4.930
# 2   05 to 09  Chanossast57  4.320
# 3   05 to 09  Eurithphos97  2.275
# 4   05 to 09       Eusri44  3.090

# %%
topS=(heroesP.groupby(["SN"])["Price"].sum()).reset_index()
topSL=topS.sort_values("Price",ascending=False).head(5)
topSL
# Out:
#               SN  Price
# 360    Lisosia93  18.96
# 246  Idastidru52  15.45
# 106   Chamjask73  13.83
# 275       Iral74  13.62
# 281  Iskadarya95  13.10

# %%
my_list=topSL["SN"].tolist()

# %%
heroes=heroesP.values.tolist()
purL=[]
for name in my_list:
    purC=0
    for row in heroes:
        if name==row[1]:
            purC=purC+1
    purL.append(purC)
purL
topSL["Purchase Count"]=purL
topSL["average Purchase Price"]=topSL["Price"]/topSL["Purchase Count"]
topSL
# Out:
#               SN  Price  Purchase Count  average Purchase Price
# 360    Lisosia93  18.96               5                3.792000
# 246  Idastidru52  15.45               4                3.862500
# 106   Chamjask73  13.83               3                4.610000
# 275       Iral74  13.62               4                3.405000
# 281  Iskadarya95  13.10               3                4.366667

# %%
topP=(heroesP.groupby(["Item ID","Item Name","Price"])["Purchase ID"].count()).reset_index()
topPL=topP.sort_values("Purchase ID",ascending=False).head(5)
topPL["Total Purchase Value"]=topPL["Price"]*topPL["Purchase ID"]
topPL
# Out:
#      Item ID                                     Item Name  Price  \
# 177      178  Oathbreaker, Last Hope of the Breaking Storm   4.23
# 144      145                          Fiery Glass Crusader   4.58
# 107      108     Extraction, Quickblade Of Trembling Hands   3.53
# 81        82                                       Nirvana   4.90
# 19        19                 Pursuit, Cudgel of Necromancy   1.02
#
#      Purchase ID  Total Purchase Value
# 177           12                 50.76
# 144            9                 41.22
# 107            9                 31.77
# 81             9                 44.10
# 19             8                  8.16
